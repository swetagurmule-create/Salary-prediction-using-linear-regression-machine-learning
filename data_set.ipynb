# %% [markdown]
# <a href="https://colab.research.google.com/github/swetagurmule-create/Salary-prediction-using-linear-regression-machine-learning/blob/main/data_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd
df=pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Salary%20Data.csv')
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
df.isnull().sum()
# Out:
# Experience Years    0
# Salary              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.mode()
# Out:
#     Experience Years  Salary
# 0                3.2   37731
# 1                4.0   39343
# 2                NaN   39891
# 3                NaN   42774
# 4                NaN   43525
# 5                NaN   46205
# 6                NaN   48266
# 7                NaN   54445
# 8                NaN   55794
# 9                NaN   56642
# 10               NaN   56957
# 11               NaN   57081
# 12               NaN   57189
# 13               NaN   59095
# 14               NaN   60000
# 15               NaN   60150
# 16               NaN   60200
# 17               NaN   61111
# 18               NaN   63218
# 19               NaN   64445
# 20               NaN   64500
# 21               NaN   66029
# 22               NaN   67938
# 23               NaN   81363
# 24               NaN   82200
# 25               NaN   83088
# 26               NaN   90000
# 27               NaN   91000
# 28               NaN   91738
# 29               NaN   93940
# 30               NaN   98273
# ...

# %%
df.mean()
# Out:
# Experience Years        5.1525
# Salary              74743.6250
# dtype: float64

# %%
df.median()
# Out:
# Experience Years        4.6
# Salary              64472.5
# dtype: float64

# %%
import matplotlib.pyplot as plt
x=df[['Experience Years']]
y=df['Salary']
plt.figure(figsize=(10,3))
plt.scatter(x,y)
plt.xlabel('Experience Year')
plt.ylabel('Salary')
plt.show()

# %%
df.shape
# Out:
# (40, 2)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=2529)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((32, 1), (8, 1), (32,), (8,))

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 96.10384373131336

# %%
lr.predict([[10]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([120326.83668364])

# %%
year=int(input("Enter you Experiance in year:"))
salary=lr.predict([[year]])
print(salary)
# Out:
# Enter you Experiance in year:7
# [92132.2431092]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
year=int(input("Enter you Experiance in year:"))
salary=lr.predict([[year]])
print(salary)
# Out:
# Enter you Experiance in year:5
# [73335.84739291]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
x=df[['Experience Years']]
y=df['Salary']
plt.figure(figsize=(10,3))
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='brown')
plt.xlabel('Experience Year')
plt.ylabel('Salary')
plt.show()
